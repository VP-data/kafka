# %%
# %pip install minio
# Out:
# Collecting minio
#   Using cached minio-7.2.18-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: argon2-cffi in c:\users\viser\anaconda3\lib\site-packages (from minio) (21.3.0)
# Requirement already satisfied: certifi in c:\users\viser\anaconda3\lib\site-packages (from minio) (2025.4.26)
# Collecting pycryptodome (from minio)
#   Using cached pycryptodome-3.23.0-cp37-abi3-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: typing-extensions in c:\users\viser\anaconda3\lib\site-packages (from minio) (4.12.2)
# Requirement already satisfied: urllib3 in c:\users\viser\anaconda3\lib\site-packages (from minio) (2.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\viser\anaconda3\lib\site-packages (from argon2-cffi->minio) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\viser\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->minio) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\viser\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio) (2.21)
# Using cached minio-7.2.18-py3-none-any.whl (93 kB)
# Using cached pycryptodome-3.23.0-cp37-abi3-win_amd64.whl (1.8 MB)
# Installing collected packages: pycryptodome, minio
#
#    ---------------------------------------- 0/2 [pycryptodome]
#    ---------------------------------------- 0/2 [pycryptodome]
#    ---------------------------------------- 0/2 [pycryptodome]
#    ---------------------------------------- 0/2 [pycryptodome]
#    -------------------- ------------------- 1/2 [minio]
#    ---------------------------------------- 2/2 [minio]
#
# Successfully installed minio-7.2.18 pycryptodome-3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import io
from minio import Minio
from minio.error import S3Error

client = Minio(
    "localhost:9000",
    access_key="minioadmin",
    secret_key="minioadmin",
    secure=False,  # HTTP no compose local
)

try:
    bucket = "teste_bucket"
    if not client.bucket_exists(bucket):
        client.make_bucket(bucket)
    client.put_object(
        bucket,
        "teste.txt",
        data=io.BytesIO(b"hello"),
        length=5,
        content_type="text/plain",
    )
    print("Upload ok")
except S3Error as e:
    print("Erro MinIO:", e)
# Out:
# Upload ok
